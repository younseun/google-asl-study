# %%
import tensorflow as tf

# %%
TIMESERIES_COL = 'height'
N_OUTPUTS = 1  # in each sequence, 1-49 are features, and 50 is label
SEQ_LEN = None
DEFAULTS = None
N_INPUTS = None

# %%
def init(hparams):
    global SEQ_LEN, DEFAULTS, N_INPUTS
    SEQ_LEN = hparams['sequence_length']
    DEFAULTS = [[0.0] for x in range(0, SEQ_LEN)]
    N_INPUTS = SEQ_LEN - N_OUTPUTS

# %%
def linear_model(features, mode, params):
    X = features[TIMESERIES_COL]
    predictions = tf.layers.dense(X, 1, activation=None)
    return predictions

# %%
def dnn_model(features, mode, params):
    X = features[TIMESERIES_COL]
    h1 = tf.layers.dense(X, 10, activation=tf.nn.relu)
    h2 = tf.layers.dense(h1, 3, activation=tf.nn.relu)
    predictions = tf.layers.dense(h2, 1, activation=None)  # linear output: regression
    return predictions

# %%
def cnn_model(features, mode, params):
    X = tf.reshape(features[TIMESERIES_COL],
                   [-1, N_INPUTS, 1])  # as a 1D "sequence" with only one time-series observation (height)
    c1 = tf.layers.conv1d(X, filters=N_INPUTS // 2,
                          kernel_size=3, strides=1,
                          padding='same', activation=tf.nn.relu)
    p1 = tf.layers.max_pooling1d(c1, pool_size=2, strides=2)

    c2 = tf.layers.conv1d(p1, filters=N_INPUTS // 2,
                          kernel_size=3, strides=1,
                          padding='same', activation=tf.nn.relu)
    p2 = tf.layers.max_pooling1d(c2, pool_size=2, strides=2)

    outlen = p2.shape[1] * p2.shape[2]
    c2flat = tf.reshape(p2, [-1, outlen])
    h1 = tf.layers.dense(c2flat, 3, activation=tf.nn.relu)
    predictions = tf.layers.dense(h1, 1, activation=None)  # linear output: regression
    return predictions

# %%
def rnn_model(features, mode, params):
    CELL_SIZE = N_INPUTS // 3  # size of the internal state in each of the cells

    # 1. dynamic_rnn needs 3D shape: [BATCH_SIZE, N_INPUTS, 1]
    x = tf.reshape(features[TIMESERIES_COL], [-1, N_INPUTS, 1])

    # 2. configure the RNN
    cell = tf.nn.rnn_cell.GRUCell(CELL_SIZE)
    outputs, state = tf.nn.dynamic_rnn(cell, x, dtype=tf.float32)

    # 3. pass rnn output through a dense layer
    h1 = tf.layers.dense(state, N_INPUTS // 2, activation=tf.nn.relu)
    predictions = tf.layers.dense(h1, 1, activation=None)  # (?, 1)
    return predictions

# %%
# 2-layer RNN
def rnn2_model(features, mode, params):
    # dynamic_rnn needs 3D shape: [BATCH_SIZE, N_INPUTS, 1]
    x = tf.reshape(features[TIMESERIES_COL], [-1, N_INPUTS, 1])

    # 2. configure the RNN
    cell1 = tf.nn.rnn_cell.GRUCell(N_INPUTS * 2)
    cell2 = tf.nn.rnn_cell.GRUCell(N_INPUTS // 2)
    cells = tf.nn.rnn_cell.MultiRNNCell([cell1, cell2])
    outputs, state = tf.nn.dynamic_rnn(cells, x, dtype=tf.float32)
    # 'state' is now a tuple containing the final state of each cell layer
    # we use state[1] below to extract the final state of the final layer
    
    # 3. pass rnn output through a dense layer
    h1 = tf.layers.dense(state[1], cells.output_size // 2, activation=tf.nn.relu)
    predictions = tf.layers.dense(h1, 1, activation=None)  # (?, 1)
    return predictions

# %%
# create N-1 predictions
def rnnN_model(features, mode, params):
    # dynamic_rnn needs 3D shape: [BATCH_SIZE, N_INPUTS, 1]
    x = tf.reshape(features[TIMESERIES_COL], [-1, N_INPUTS, 1])

    # 2. configure the RNN
    cell1 = tf.nn.rnn_cell.GRUCell(N_INPUTS * 2)
    cell2 = tf.nn.rnn_cell.GRUCell(N_INPUTS // 2)
    cells = tf.nn.rnn_cell.MultiRNNCell([cell1, cell2])
    outputs, state = tf.nn.dynamic_rnn(cells, x, dtype=tf.float32)
    # 'outputs' contains the state of the final layer for every time step
    # not just the last time step (?,N_INPUTS, final cell size)
    
    # 3. pass state for each time step through a DNN, to get a prediction
    # for each time step 
    h1 = tf.layers.dense(outputs, cells.output_size, activation=tf.nn.relu)
    h2 = tf.layers.dense(h1, cells.output_size // 2, activation=tf.nn.relu)
    predictions = tf.layers.dense(h2, 1, activation=None)  # (?, N_INPUTS, 1)
    predictions = tf.reshape(predictions, [-1, N_INPUTS])
    return predictions # return prediction for each time step

# %%
# read data and convert to needed format
def read_dataset(filename, mode, batch_size=512):
    def _input_fn():
        def decode_csv(row):
            # row is a string tensor containing the contents of one row
            features = tf.decode_csv(row, record_defaults=DEFAULTS)  # string tensor -> list of 50 rank 0 float tensors
            label = features.pop()  # remove last feature and use as label
            features = tf.stack(features)  # list of rank 0 tensors -> single rank 1 tensor
            return {TIMESERIES_COL: features}, label

        # Create list of file names that match "glob" pattern (i.e. data_file_*.csv)
        dataset = tf.data.Dataset.list_files(filename)
        # Read in data from files
        dataset = dataset.flat_map(tf.data.TextLineDataset)
        # Parse text lines as comma-separated values (CSV)
        dataset = dataset.map(decode_csv)

        if mode == tf.estimator.ModeKeys.TRAIN:
            num_epochs = None  # loop indefinitely
            dataset = dataset.shuffle(buffer_size=10 * batch_size)
        else:
            num_epochs = 1  # end-of-input after this

        dataset = dataset.repeat(num_epochs).batch(batch_size)
        return dataset.make_one_shot_iterator().get_next()

    return _input_fn

# %%
def serving_input_fn():
    feature_placeholders = {
        TIMESERIES_COL: tf.placeholder(tf.float32, [None, N_INPUTS])
    }

    features = {
        key: tf.expand_dims(tensor, -1)
        for key, tensor in feature_placeholders.items()
    }
    features[TIMESERIES_COL] = tf.squeeze(features[TIMESERIES_COL], axis=[2])

    return tf.estimator.export.ServingInputReceiver(features, feature_placeholders)

# %%
def compute_errors(features, labels, predictions):
    labels = tf.expand_dims(labels, -1)  # rank 1 -> rank 2 to match rank of predictions

    if predictions.shape[1] == 1:
        loss = tf.losses.mean_squared_error(labels, predictions)
        rmse = tf.metrics.root_mean_squared_error(labels, predictions)
        return loss, rmse
    else:
        # one prediction for every input in sequence
        # get 1-N of (x + label)
        labelsN = tf.concat([features[TIMESERIES_COL], labels], axis=1)
        labelsN = labelsN[:, 1:]
        # loss is computed from the last 1/3 of the series
        N = (2 * N_INPUTS) // 3
        loss = tf.losses.mean_squared_error(labelsN[:, N:], predictions[:, N:])
        # rmse is computed from last prediction and last label
        lastPred = predictions[:, -1]
        rmse = tf.metrics.root_mean_squared_error(labels, lastPred)
        return loss, rmse

# %%
# RMSE when predicting same as last value
def same_as_last_benchmark(features, labels):
    predictions = features[TIMESERIES_COL][:,-1] # last value in input sequence
    return tf.metrics.root_mean_squared_error(labels, predictions)

# %%
# create the inference model
def sequence_regressor(features, labels, mode, params):
    # 1. run the appropriate model
    model_functions = {
        'linear': linear_model,
        'dnn': dnn_model,
        'cnn': cnn_model,
        'rnn': rnn_model,
        'rnn2': rnn2_model,
        'rnnN': rnnN_model}
    model_function = model_functions[params['model']]
    predictions = model_function(features, mode, params)

    # 2. loss function, training/eval ops
    loss = None
    train_op = None
    eval_metric_ops = None
    if mode == tf.estimator.ModeKeys.TRAIN or mode == tf.estimator.ModeKeys.EVAL:
        loss, rmse = compute_errors(features, labels, predictions)

        if mode == tf.estimator.ModeKeys.TRAIN:
            # this is needed for batch normalization, but has no effect otherwise
            update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
            with tf.control_dependencies(update_ops):
                # 2b. set up training operation
                train_op = tf.contrib.layers.optimize_loss(
                    loss,
                    tf.train.get_global_step(),
                    learning_rate=params['learning_rate'],
                    optimizer="Adam")

        # 2c. eval metric
        eval_metric_ops = {
            "RMSE": rmse,
            "RMSE_same_as_last": same_as_last_benchmark(features, labels),
        }

    # 3. Create predictions
    if predictions.shape[1] != 1:
        predictions = predictions[:, -1]  # last predicted value
    predictions_dict = {"predicted": predictions}

    # 4. return EstimatorSpec
    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions=predictions_dict,
        loss=loss,
        train_op=train_op,
        eval_metric_ops=eval_metric_ops,
        export_outputs={
            'predictions': tf.estimator.export.PredictOutput(predictions_dict)}
    )

# %%
def train_and_evaluate(output_dir, hparams):
    tf.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
    get_train = read_dataset(hparams['train_data_path'],
                             tf.estimator.ModeKeys.TRAIN,
                             hparams['train_batch_size'])
    get_valid = read_dataset(hparams['eval_data_path'],
                             tf.estimator.ModeKeys.EVAL,
                             1000)
    estimator = tf.estimator.Estimator(model_fn=sequence_regressor,
                                       params=hparams,
                                       config=tf.estimator.RunConfig(
                                           save_checkpoints_secs=
                                           hparams['min_eval_frequency']),
                                       model_dir=output_dir)
    train_spec = tf.estimator.TrainSpec(input_fn=get_train,
                                        max_steps=hparams['train_steps'])
    exporter = tf.estimator.LatestExporter('exporter', serving_input_fn)
    eval_spec = tf.estimator.EvalSpec(input_fn=get_valid,
                                      steps=None,
                                      exporters=exporter,
                                      start_delay_secs=hparams['eval_delay_secs'],
                                      throttle_secs=hparams['min_eval_frequency'])
    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="linear"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_global_id_in_cluster': 0, '_task_type': 'worker', '_experimental_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_train_distribute': None, '_master': '', '_log_step_count_steps': 100, '_evaluation_master': '', '_save_checkpoints_steps': None, '_model_dir': './trained_linear/sines', '_protocol': None, '_device_fn': None, '_service': None, '_session_creation_timeout_secs': 7200, '_tf_random_seed': None, '_is_chief': True, '_num_worker_replicas': 1, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcdb01019e8>, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_task_id': 0}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Skipping training since max_steps has already saved.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="dnn"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_global_id_in_cluster': 0, '_task_type': 'worker', '_experimental_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_train_distribute': None, '_master': '', '_log_step_count_steps': 100, '_evaluation_master': '', '_save_checkpoints_steps': None, '_model_dir': './trained_dnn/sines', '_protocol': None, '_device_fn': None, '_service': None, '_session_creation_timeout_secs': 7200, '_tf_random_seed': None, '_is_chief': True, '_num_worker_replicas': 1, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcdbeb758d0>, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_task_id': 0}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_dnn/sines/model.ckpt.
# INFO:tensorflow:loss = 0.6617853, step = 1
# INFO:tensorflow:global_step/sec: 15.2764
# INFO:tensorflow:loss = 0.042142235, step = 101 (6.548 sec)
# INFO:tensorflow:global_step/sec: 16.23
# INFO:tensorflow:loss = 0.02479499, step = 201 (6.162 sec)
# INFO:tensorflow:global_step/sec: 16.0197
# INFO:tensorflow:loss = 0.025493858, step = 301 (6.242 sec)
# INFO:tensorflow:global_step/sec: 16.5914
# INFO:tensorflow:loss = 0.01912841, step = 401 (6.027 sec)
# INFO:tensorflow:global_step/sec: 16.228
# INFO:tensorflow:loss = 0.016472062, step = 501 (6.165 sec)
# INFO:tensorflow:global_step/sec: 16.1588
# INFO:tensorflow:loss = 0.011157616, step = 601 (6.186 sec)
# INFO:tensorflow:global_step/sec: 16.1628
# INFO:tensorflow:loss = 0.012315004, step = 701 (6.187 sec)
# INFO:tensorflow:global_step/sec: 16.4603
# INFO:tensorflow:loss = 0.013762694, step = 801 (6.075 sec)
# INFO:tensorflow:global_step/sec: 16.6988
# INFO:tensorflow:loss = 0.008999806, step = 901 (5.989 sec)
# INFO:tensorflow:Saving checkpoints for 961 into ./trained_dnn/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:43:19Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_dnn/sines/model.ckpt-961
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:43:22
# INFO:tensorflow:Saving dict for global step 961: RMSE = 0.10521794, RMSE_same_as_last = 0.31125915, global_step = 961, loss = 0.0111042755
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 961: ./trained_dnn/sines/model.ckpt-961
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_dnn/sines/model.ckpt-961
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_dnn/sines/export/exporter/temp-b'1575726202'/saved_model.pb
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_dnn/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:43:25Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_dnn/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:43:28
# INFO:tensorflow:Saving dict for global step 1000: RMSE = 0.1028588, RMSE_same_as_last = 0.31125915, global_step = 1000, loss = 0.010487646
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_dnn/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_dnn/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_dnn/sines/export/exporter/temp-b'1575726208'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.013383869.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="cnn"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_global_id_in_cluster': 0, '_task_type': 'worker', '_experimental_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_train_distribute': None, '_master': '', '_log_step_count_steps': 100, '_evaluation_master': '', '_save_checkpoints_steps': None, '_model_dir': './trained_cnn/sines', '_protocol': None, '_device_fn': None, '_service': None, '_session_creation_timeout_secs': 7200, '_tf_random_seed': None, '_is_chief': True, '_num_worker_replicas': 1, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcdb3cd96a0>, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_task_id': 0}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-34-09a978e2bc0d>:6: conv1d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv1D` instead.
# WARNING:tensorflow:From <ipython-input-34-09a978e2bc0d>:7: max_pooling1d (from tensorflow.python.layers.pooling) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.MaxPooling1D instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_cnn/sines/model.ckpt.
# INFO:tensorflow:loss = 0.59889495, step = 1
# INFO:tensorflow:global_step/sec: 14.3256
# INFO:tensorflow:loss = 0.0188467, step = 101 (6.986 sec)
# INFO:tensorflow:global_step/sec: 15.3477
# INFO:tensorflow:loss = 0.022182228, step = 201 (6.513 sec)
# INFO:tensorflow:global_step/sec: 10.933
# INFO:tensorflow:loss = 0.012556892, step = 301 (9.146 sec)
# INFO:tensorflow:global_step/sec: 15.4139
# INFO:tensorflow:loss = 0.012753499, step = 401 (6.492 sec)
# INFO:tensorflow:global_step/sec: 15.154
# INFO:tensorflow:loss = 0.012757034, step = 501 (6.599 sec)
# INFO:tensorflow:global_step/sec: 14.8326
# INFO:tensorflow:loss = 0.01327439, step = 601 (6.739 sec)
# INFO:tensorflow:global_step/sec: 15.7901
# INFO:tensorflow:loss = 0.008253742, step = 701 (6.333 sec)
# INFO:tensorflow:global_step/sec: 15.3815
# INFO:tensorflow:loss = 0.014961801, step = 801 (6.501 sec)
# INFO:tensorflow:Saving checkpoints for 859 into ./trained_cnn/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:44:30Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_cnn/sines/model.ckpt-859
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:44:33
# INFO:tensorflow:Saving dict for global step 859: RMSE = 0.1090933, RMSE_same_as_last = 0.31125915, global_step = 859, loss = 0.011677142
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 859: ./trained_cnn/sines/model.ckpt-859
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_cnn/sines/model.ckpt-859
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_cnn/sines/export/exporter/temp-b'1575726273'/saved_model.pb
# INFO:tensorflow:global_step/sec: 9.43392
# INFO:tensorflow:loss = 0.01223625, step = 901 (10.603 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_cnn/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:44:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_cnn/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:44:47
# INFO:tensorflow:Saving dict for global step 1000: RMSE = 0.108241454, RMSE_same_as_last = 0.31125915, global_step = 1000, loss = 0.011719643
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_cnn/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_cnn/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_cnn/sines/export/exporter/temp-b'1575726287'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.013730015.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="rnn"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_global_id_in_cluster': 0, '_task_type': 'worker', '_experimental_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_train_distribute': None, '_master': '', '_log_step_count_steps': 100, '_evaluation_master': '', '_save_checkpoints_steps': None, '_model_dir': './trained_rnn/sines', '_protocol': None, '_device_fn': None, '_service': None, '_session_creation_timeout_secs': 7200, '_tf_random_seed': None, '_is_chief': True, '_num_worker_replicas': 1, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcd6c118198>, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_task_id': 0}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-35-a8e1e3d9ec7b>:8: GRUCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.GRUCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-35-a8e1e3d9ec7b>:9: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:559: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:565: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:575: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_rnn/sines/model.ckpt.
# INFO:tensorflow:loss = 0.4834612, step = 1
# INFO:tensorflow:global_step/sec: 8.30726
# INFO:tensorflow:loss = 0.020635782, step = 101 (12.040 sec)
# INFO:tensorflow:global_step/sec: 8.93045
# INFO:tensorflow:loss = 0.015722858, step = 201 (11.198 sec)
# INFO:tensorflow:global_step/sec: 8.62639
# INFO:tensorflow:loss = 0.013608498, step = 301 (11.592 sec)
# INFO:tensorflow:global_step/sec: 8.60582
# INFO:tensorflow:loss = 0.013433975, step = 401 (11.620 sec)
# INFO:tensorflow:global_step/sec: 8.82139
# INFO:tensorflow:loss = 0.012252183, step = 501 (11.336 sec)
# INFO:tensorflow:Saving checkpoints for 507 into ./trained_rnn/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:45:49Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-507
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:45:53
# INFO:tensorflow:Saving dict for global step 507: RMSE = 0.11101213, RMSE_same_as_last = 0.31125915, global_step = 507, loss = 0.012673403
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 507: ./trained_rnn/sines/model.ckpt-507
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-507
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn/sines/export/exporter/temp-b'1575726353'/saved_model.pb
# INFO:tensorflow:global_step/sec: 6.20545
# INFO:tensorflow:loss = 0.012553259, step = 601 (16.115 sec)
# INFO:tensorflow:global_step/sec: 8.33521
# INFO:tensorflow:loss = 0.012122107, step = 701 (11.997 sec)
# INFO:tensorflow:global_step/sec: 8.70628
# INFO:tensorflow:loss = 0.009258109, step = 801 (11.485 sec)
# INFO:tensorflow:global_step/sec: 8.65318
# INFO:tensorflow:loss = 0.013530568, step = 901 (11.557 sec)
# INFO:tensorflow:Saving checkpoints for 983 into ./trained_rnn/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:46:49Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-983
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:46:53
# INFO:tensorflow:Saving dict for global step 983: RMSE = 0.10673423, RMSE_same_as_last = 0.31125915, global_step = 983, loss = 0.011537946
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 983: ./trained_rnn/sines/model.ckpt-983
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-983
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn/sines/export/exporter/temp-b'1575726413'/saved_model.pb
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_rnn/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:46:56Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:47:00
# INFO:tensorflow:Saving dict for global step 1000: RMSE = 0.11175247, RMSE_same_as_last = 0.31125915, global_step = 1000, loss = 0.012575313
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_rnn/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn/sines/export/exporter/temp-b'1575726420'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.012753555.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="rnn2"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_global_id_in_cluster': 0, '_task_type': 'worker', '_experimental_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_train_distribute': None, '_master': '', '_log_step_count_steps': 100, '_evaluation_master': '', '_save_checkpoints_steps': None, '_model_dir': './trained_rnn2/sines', '_protocol': None, '_device_fn': None, '_service': None, '_session_creation_timeout_secs': 7200, '_tf_random_seed': None, '_is_chief': True, '_num_worker_replicas': 1, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcd11c250f0>, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_task_id': 0}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From <ipython-input-36-f0efd443ffec>:9: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:loss = 0.59032035, step = 1
# INFO:tensorflow:global_step/sec: 5.65329
# INFO:tensorflow:loss = 0.011768964, step = 101 (17.695 sec)
# INFO:tensorflow:global_step/sec: 5.77616
# INFO:tensorflow:loss = 0.016794054, step = 201 (17.309 sec)
# INFO:tensorflow:global_step/sec: 5.86523
# INFO:tensorflow:loss = 0.014014958, step = 301 (17.050 sec)
# INFO:tensorflow:Saving checkpoints for 336 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:48:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-336
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:48:08
# INFO:tensorflow:Saving dict for global step 336: RMSE = 0.11338018, RMSE_same_as_last = 0.31125915, global_step = 336, loss = 0.012641009
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 336: ./trained_rnn2/sines/model.ckpt-336
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-336
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575726488'/saved_model.pb
# INFO:tensorflow:global_step/sec: 4.44602
# INFO:tensorflow:loss = 0.01254502, step = 401 (22.492 sec)
# INFO:tensorflow:global_step/sec: 5.87585
# INFO:tensorflow:loss = 0.01612264, step = 501 (17.018 sec)
# INFO:tensorflow:global_step/sec: 5.75003
# INFO:tensorflow:loss = 0.010521053, step = 601 (17.392 sec)
# INFO:tensorflow:Saving checkpoints for 653 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:49:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-653
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:49:08
# INFO:tensorflow:Saving dict for global step 653: RMSE = 0.10529498, RMSE_same_as_last = 0.31125915, global_step = 653, loss = 0.01102905
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 653: ./trained_rnn2/sines/model.ckpt-653
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-653
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575726548'/saved_model.pb
# INFO:tensorflow:global_step/sec: 4.49012
# INFO:tensorflow:loss = 0.013216722, step = 701 (22.271 sec)
# INFO:tensorflow:global_step/sec: 5.77658
# INFO:tensorflow:loss = 0.008854427, step = 801 (17.311 sec)
# INFO:tensorflow:global_step/sec: 5.69733
# INFO:tensorflow:loss = 0.010525822, step = 901 (17.556 sec)
# INFO:tensorflow:Saving checkpoints for 970 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:50:03Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-970
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:50:07
# INFO:tensorflow:Saving dict for global step 970: RMSE = 0.10197008, RMSE_same_as_last = 0.31125915, global_step = 970, loss = 0.010280099
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 970: ./trained_rnn2/sines/model.ckpt-970
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-970
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575726607'/saved_model.pb
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:50:13Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:50:17
# INFO:tensorflow:Saving dict for global step 1000: RMSE = 0.10101437, RMSE_same_as_last = 0.31125915, global_step = 1000, loss = 0.010070217
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_rnn2/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575726617'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.011438358.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="rnnN"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_global_id_in_cluster': 0, '_task_type': 'worker', '_experimental_distribute': None, '_keep_checkpoint_every_n_hours': 10000, '_train_distribute': None, '_master': '', '_log_step_count_steps': 100, '_evaluation_master': '', '_save_checkpoints_steps': None, '_model_dir': './trained_rnnN/sines', '_protocol': None, '_device_fn': None, '_service': None, '_session_creation_timeout_secs': 7200, '_tf_random_seed': None, '_is_chief': True, '_num_worker_replicas': 1, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_eval_distribute': None, '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcda00bf2b0>, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_task_id': 0}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_rnnN/sines/model.ckpt.
# INFO:tensorflow:loss = 0.6009569, step = 1
# INFO:tensorflow:global_step/sec: 5.26643
# INFO:tensorflow:loss = 0.011885406, step = 101 (18.990 sec)
# INFO:tensorflow:global_step/sec: 5.60188
# INFO:tensorflow:loss = 0.010457868, step = 201 (17.851 sec)
# INFO:tensorflow:global_step/sec: 5.50593
# INFO:tensorflow:loss = 0.01043108, step = 301 (18.163 sec)
# INFO:tensorflow:Saving checkpoints for 316 into ./trained_rnnN/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:51:21Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnnN/sines/model.ckpt-316
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:51:26
# INFO:tensorflow:Saving dict for global step 316: RMSE = 0.09876348, RMSE_same_as_last = 0.31125915, global_step = 316, loss = 0.01014822
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 316: ./trained_rnnN/sines/model.ckpt-316
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnnN/sines/model.ckpt-316
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnnN/sines/export/exporter/temp-b'1575726686'/saved_model.pb
# INFO:tensorflow:global_step/sec: 4.26188
# INFO:tensorflow:loss = 0.010525886, step = 401 (23.463 sec)
# INFO:tensorflow:global_step/sec: 5.61188
# INFO:tensorflow:loss = 0.010843574, step = 501 (17.820 sec)
# INFO:tensorflow:global_step/sec: 5.60767
# INFO:tensorflow:loss = 0.009798867, step = 601 (17.833 sec)
# INFO:tensorflow:Saving checkpoints for 621 into ./trained_rnnN/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:52:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnnN/sines/model.ckpt-621
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:52:26
# INFO:tensorflow:Saving dict for global step 621: RMSE = 0.096628554, RMSE_same_as_last = 0.31125915, global_step = 621, loss = 0.009576322
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 621: ./trained_rnnN/sines/model.ckpt-621
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnnN/sines/model.ckpt-621
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnnN/sines/export/exporter/temp-b'1575726746'/saved_model.pb
# INFO:tensorflow:global_step/sec: 4.31142
# INFO:tensorflow:loss = 0.010055717, step = 701 (23.194 sec)
# INFO:tensorflow:global_step/sec: 5.5118
# INFO:tensorflow:loss = 0.009865743, step = 801 (18.142 sec)
# INFO:tensorflow:global_step/sec: 5.54496
# INFO:tensorflow:loss = 0.010285714, step = 901 (18.035 sec)
# INFO:tensorflow:Saving checkpoints for 926 into ./trained_rnnN/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:53:22Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnnN/sines/model.ckpt-926
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:53:26
# INFO:tensorflow:Saving dict for global step 926: RMSE = 0.09797479, RMSE_same_as_last = 0.31125915, global_step = 926, loss = 0.009659704
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 926: ./trained_rnnN/sines/model.ckpt-926
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnnN/sines/model.ckpt-926
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnnN/sines/export/exporter/temp-b'1575726806'/saved_model.pb
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_rnnN/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T13:53:40Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnnN/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-13:53:44
# INFO:tensorflow:Saving dict for global step 1000: RMSE = 0.09641499, RMSE_same_as_last = 0.31125915, global_step = 1000, loss = 0.00946505
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_rnnN/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'predictions']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from ./trained_rnnN/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnnN/sines/export/exporter/temp-b'1575726824'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.009413472.
