# %%
import tensorflow as tf

# %%
TIMESERIES_COL = 'height'
N_OUTPUTS = 1  # in each sequence, 1-49 are features, and 50 is label
SEQ_LEN = None
DEFAULTS = None
N_INPUTS = None

# %%
def init(hparams):
    global SEQ_LEN, DEFAULTS, N_INPUTS
    SEQ_LEN = hparams['sequence_length']
    DEFAULTS = [[0.0] for x in range(0, SEQ_LEN)]
    N_INPUTS = SEQ_LEN - N_OUTPUTS

# %%
def linear_model(hparams):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.InputLayer(input_shape = [N_INPUTS], name = TIMESERIES_COL))
    model.add(tf.keras.layers.Dense(units = 1, activation = None))
    return model

# %%
def dnn_model(hparams):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.InputLayer(input_shape = [N_INPUTS], name = TIMESERIES_COL))
    model.add(tf.keras.layers.Dense(units = 30, activation = tf.nn.relu))
    model.add(tf.keras.layers.Dense(units = 10, activation = tf.nn.relu))
    model.add(tf.keras.layers.Dense(units = 1, activation = None))
    return model

# %%
def cnn_model(hparams):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.InputLayer(input_shape = [N_INPUTS], name = TIMESERIES_COL))
    model.add(tf.keras.layers.Reshape(target_shape = [N_INPUTS, 1]))
    model.add(tf.keras.layers.Conv1D(filters = N_INPUTS // 2, kernel_size = 3, padding = "same", activation = tf.nn.relu))
    model.add(tf.keras.layers.MaxPooling1D(pool_size = 2, strides = 2))
    model.add(tf.keras.layers.Conv1D(filters = N_INPUTS // 2, kernel_size = 3, padding = "same", activation = tf.nn.relu))
    model.add(tf.keras.layers.MaxPooling1D(pool_size = 2, strides = 2))
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(units = 3, activation = tf.nn.relu))
    model.add(tf.keras.layers.Dense(units = 1, activation = None))
    return model

# %%
def rnn_model(hparams):
    CELL_SIZE = N_INPUTS // 3  # size of the internal state in each of the cells

    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.InputLayer(input_shape = [N_INPUTS], name = TIMESERIES_COL))
    model.add(tf.keras.layers.Reshape(target_shape = [N_INPUTS, 1]))
    model.add(tf.keras.layers.LSTM(units = CELL_SIZE))
    model.add(tf.keras.layers.Dense(units = N_INPUTS // 2, activation = tf.nn.relu))
    model.add(tf.keras.layers.Dense(units = 1, activation = None))
    return model

# %%
# 2-layer RNN
def rnn2_model(hparams):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.InputLayer(input_shape = [N_INPUTS], name = TIMESERIES_COL))
    model.add(tf.keras.layers.Reshape(target_shape = [N_INPUTS, 1]))
    model.add(tf.keras.layers.LSTM(units = N_INPUTS * 2, return_sequences = True))
    model.add(tf.keras.layers.LSTM(units = N_INPUTS // 2))
    model.add(tf.keras.layers.Dense(units = (N_INPUTS // 2) // 2, activation = tf.nn.relu))
    model.add(tf.keras.layers.Dense(units = 1, activation = None))
    return model

# %%
# read data and convert to needed format
def read_dataset(filename, mode, batch_size=512):
    def _input_fn():
        def decode_csv(row):
            # row is a string tensor containing the contents of one row
            features = tf.decode_csv(row, record_defaults=DEFAULTS)  # string tensor -> list of 50 rank 0 float tensors
            label = features.pop()  # remove last feature and use as label
            features = tf.stack(features)  # list of rank 0 tensors -> single rank 1 tensor
            return {TIMESERIES_COL: features}, label

        # Create list of file names that match "glob" pattern (i.e. data_file_*.csv)
        dataset = tf.data.Dataset.list_files(filename)
        # Read in data from files
        dataset = dataset.flat_map(tf.data.TextLineDataset)
        # Parse text lines as comma-separated values (CSV)
        dataset = dataset.map(decode_csv)

        if mode == tf.estimator.ModeKeys.TRAIN:
            num_epochs = None  # loop indefinitely
            dataset = dataset.shuffle(buffer_size=10 * batch_size)
        else:
            num_epochs = 1  # end-of-input after this

        dataset = dataset.repeat(num_epochs).batch(batch_size)
        return dataset.make_one_shot_iterator().get_next()

    return _input_fn

# %%
def serving_input_fn():
    feature_placeholders = {
        TIMESERIES_COL: tf.placeholder(tf.float32, [None, N_INPUTS])
    }

    features = {
        key: tf.expand_dims(tensor, -1)
        for key, tensor in feature_placeholders.items()
    }
    features[TIMESERIES_COL] = tf.squeeze(features[TIMESERIES_COL], axis=[2])

    return tf.estimator.export.ServingInputReceiver(features, feature_placeholders)

# %%
# Wrapper function to build selected Keras model type
def sequence_regressor(hparams):
    # 1. Run the appropriate model
    model_functions = {
        "linear": linear_model,
        "dnn": dnn_model,
        "cnn": cnn_model,
        "rnn": rnn_model,
        "rnn2": rnn2_model}
    
    # Get function pointer for selected model type
    model_function = model_functions[hparams["model"]]
    
    # Build selected Keras model
    model = model_function(hparams)
    
    return model

# %%
def train_and_evaluate(output_dir, hparams):
    tf.summary.FileWriterCache.clear() # ensure filewriter cache is clear for TensorBoard events file
    
    # Build Keras model
    model = sequence_regressor(hparams)
    
    # Compile Keras model with optimizer, loss function, and eval metrics
    model.compile(
        optimizer = "adam",
        loss = "mse",
        metrics = ["mse"])
        
    # Convert Keras model to an Estimator
    estimator = tf.keras.estimator.model_to_estimator(
        keras_model = model, 
        model_dir = output_dir, 
        config = tf.estimator.RunConfig(save_checkpoints_secs = hparams["min_eval_frequency"]))
    
    # Set estimator's train_spec to use train_input_fn and train for so many steps
    train_spec = tf.estimator.TrainSpec(
        input_fn = read_dataset(
            filename = hparams['train_data_path'],
            mode = tf.estimator.ModeKeys.TRAIN,
            batch_size = hparams['train_batch_size']),
        max_steps = hparams['train_steps'])
    
    # Create exporter that uses serving_input_fn to create saved_model for serving
    exporter = tf.estimator.LatestExporter(name = 'exporter', serving_input_receiver_fn = serving_input_fn)
    
    # Set estimator's eval_spec to use eval_input_fn and export saved_model
    eval_spec = tf.estimator.EvalSpec(
        input_fn = read_dataset(
            filename = hparams['eval_data_path'],
            mode = tf.estimator.ModeKeys.EVAL,
            batch_size = 1000),
        steps = None,
        exporters = exporter,
        start_delay_secs = hparams['eval_delay_secs'],
        throttle_secs = hparams['min_eval_frequency'])
    
    # Run train_and_evaluate loop
    tf.estimator.train_and_evaluate(
        estimator = estimator, 
        train_spec = train_spec, 
        eval_spec = eval_spec)

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="linear"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Using the Keras model provided.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Using config: {'_train_distribute': None, '_global_id_in_cluster': 0, '_protocol': None, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_session_creation_timeout_secs': 7200, '_device_fn': None, '_save_checkpoints_steps': None, '_task_id': 0, '_eval_distribute': None, '_evaluation_master': '', '_master': '', '_num_ps_replicas': 0, '_is_chief': True, '_task_type': 'worker', '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_service': None, '_model_dir': './trained_linear/sines', '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_experimental_distribute': None, '_log_step_count_steps': 100, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9693838278>, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.decode_csv is deprecated. Please use tf.io.decode_csv instead.
#
# WARNING:tensorflow:From <ipython-input-9-8a948d343e5e>:25: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='./trained_linear/sines/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ./trained_linear/sines/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 2 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_linear/sines/model.ckpt.
# INFO:tensorflow:loss = 3.770997, step = 1
# INFO:tensorflow:global_step/sec: 19.6033
# INFO:tensorflow:loss = 0.8821442, step = 101 (5.103 sec)
# INFO:tensorflow:global_step/sec: 20.8894
# INFO:tensorflow:loss = 0.50583315, step = 201 (4.787 sec)
# INFO:tensorflow:global_step/sec: 21.3374
# INFO:tensorflow:loss = 0.6695647, step = 301 (4.686 sec)
# INFO:tensorflow:global_step/sec: 20.3525
# INFO:tensorflow:loss = 0.6238985, step = 401 (4.914 sec)
# INFO:tensorflow:global_step/sec: 20.8166
# INFO:tensorflow:loss = 0.52291155, step = 501 (4.804 sec)
# INFO:tensorflow:global_step/sec: 21.89
# INFO:tensorflow:loss = 0.60191476, step = 601 (4.569 sec)
# INFO:tensorflow:global_step/sec: 21.9063
# INFO:tensorflow:loss = 0.60304594, step = 701 (4.565 sec)
# INFO:tensorflow:global_step/sec: 21.6218
# INFO:tensorflow:loss = 0.5816387, step = 801 (4.625 sec)
# INFO:tensorflow:global_step/sec: 21.0905
# INFO:tensorflow:loss = 0.59305185, step = 901 (4.742 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_linear/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:09:51Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_linear/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:09:54
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.5463782, mean_squared_error = 0.53926665
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_linear/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_linear/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_linear/sines/export/exporter/temp-b'1575727794'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.46048808.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="dnn"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_train_distribute': None, '_global_id_in_cluster': 0, '_protocol': None, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_session_creation_timeout_secs': 7200, '_device_fn': None, '_save_checkpoints_steps': None, '_task_id': 0, '_eval_distribute': None, '_evaluation_master': '', '_master': '', '_num_ps_replicas': 0, '_is_chief': True, '_task_type': 'worker', '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_service': None, '_model_dir': './trained_dnn/sines', '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_experimental_distribute': None, '_log_step_count_steps': 100, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f95b05b3e48>, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='./trained_dnn/sines/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ./trained_dnn/sines/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 6 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_dnn/sines/model.ckpt.
# INFO:tensorflow:loss = 0.9584497, step = 1
# INFO:tensorflow:global_step/sec: 15.2302
# INFO:tensorflow:loss = 0.5506106, step = 101 (6.569 sec)
# INFO:tensorflow:global_step/sec: 16.0922
# INFO:tensorflow:loss = 0.536156, step = 201 (6.214 sec)
# INFO:tensorflow:global_step/sec: 16.3781
# INFO:tensorflow:loss = 0.4921831, step = 301 (6.109 sec)
# INFO:tensorflow:global_step/sec: 16.276
# INFO:tensorflow:loss = 0.5384848, step = 401 (6.144 sec)
# INFO:tensorflow:global_step/sec: 16.2682
# INFO:tensorflow:loss = 0.60904956, step = 501 (6.143 sec)
# INFO:tensorflow:global_step/sec: 16.0949
# INFO:tensorflow:loss = 0.5365905, step = 601 (6.213 sec)
# INFO:tensorflow:global_step/sec: 16.248
# INFO:tensorflow:loss = 0.44474947, step = 701 (6.155 sec)
# INFO:tensorflow:global_step/sec: 15.8571
# INFO:tensorflow:loss = 0.45858753, step = 801 (6.306 sec)
# INFO:tensorflow:global_step/sec: 16.2321
# INFO:tensorflow:loss = 0.4689159, step = 901 (6.164 sec)
# INFO:tensorflow:Saving checkpoints for 951 into ./trained_dnn/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:11:31Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_dnn/sines/model.ckpt-951
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:11:34
# INFO:tensorflow:Saving dict for global step 951: global_step = 951, loss = 0.53657943, mean_squared_error = 0.53008944
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 951: ./trained_dnn/sines/model.ckpt-951
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_dnn/sines/model.ckpt-951
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_dnn/sines/export/exporter/temp-b'1575727894'/saved_model.pb
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_dnn/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:11:37Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_dnn/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:11:40
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.5261254, mean_squared_error = 0.5255178
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_dnn/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_dnn/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_dnn/sines/export/exporter/temp-b'1575727900'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.46872747.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="cnn"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_train_distribute': None, '_global_id_in_cluster': 0, '_protocol': None, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_session_creation_timeout_secs': 7200, '_device_fn': None, '_save_checkpoints_steps': None, '_task_id': 0, '_eval_distribute': None, '_evaluation_master': '', '_master': '', '_num_ps_replicas': 0, '_is_chief': True, '_task_type': 'worker', '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_service': None, '_model_dir': './trained_cnn/sines', '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_experimental_distribute': None, '_log_step_count_steps': 100, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f95f52900b8>, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='./trained_cnn/sines/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ./trained_cnn/sines/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 8 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_cnn/sines/model.ckpt.
# INFO:tensorflow:loss = 0.5617476, step = 1
# INFO:tensorflow:global_step/sec: 14.4598
# INFO:tensorflow:loss = 0.49740642, step = 101 (6.921 sec)
# INFO:tensorflow:global_step/sec: 14.8797
# INFO:tensorflow:loss = 0.52693933, step = 201 (6.717 sec)
# INFO:tensorflow:global_step/sec: 14.9014
# INFO:tensorflow:loss = 0.6557995, step = 301 (6.710 sec)
# INFO:tensorflow:global_step/sec: 15.4526
# INFO:tensorflow:loss = 0.48510242, step = 401 (6.472 sec)
# INFO:tensorflow:global_step/sec: 15.6833
# INFO:tensorflow:loss = 0.6299198, step = 501 (6.376 sec)
# INFO:tensorflow:global_step/sec: 15.4891
# INFO:tensorflow:loss = 0.5628208, step = 601 (6.456 sec)
# INFO:tensorflow:global_step/sec: 15.3844
# INFO:tensorflow:loss = 0.5518704, step = 701 (6.500 sec)
# INFO:tensorflow:global_step/sec: 15.0443
# INFO:tensorflow:loss = 0.54392374, step = 801 (6.648 sec)
# INFO:tensorflow:Saving checkpoints for 894 into ./trained_cnn/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:12:43Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_cnn/sines/model.ckpt-894
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:12:46
# INFO:tensorflow:Saving dict for global step 894: global_step = 894, loss = 0.5306266, mean_squared_error = 0.5217181
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 894: ./trained_cnn/sines/model.ckpt-894
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_cnn/sines/model.ckpt-894
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_cnn/sines/export/exporter/temp-b'1575727966'/saved_model.pb
# INFO:tensorflow:global_step/sec: 9.39333
# INFO:tensorflow:loss = 0.64042777, step = 901 (10.646 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_cnn/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:12:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_cnn/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:12:57
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.5327854, mean_squared_error = 0.5236096
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_cnn/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_cnn/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_cnn/sines/export/exporter/temp-b'1575727977'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.5212229.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="rnn"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using the Keras model provided.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Using config: {'_train_distribute': None, '_global_id_in_cluster': 0, '_protocol': None, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_session_creation_timeout_secs': 7200, '_device_fn': None, '_save_checkpoints_steps': None, '_task_id': 0, '_eval_distribute': None, '_evaluation_master': '', '_master': '', '_num_ps_replicas': 0, '_is_chief': True, '_task_type': 'worker', '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_service': None, '_model_dir': './trained_rnn/sines', '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_experimental_distribute': None, '_log_step_count_steps': 100, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f95f5596518>, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='./trained_rnn/sines/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ./trained_rnn/sines/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 7 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_rnn/sines/model.ckpt.
# INFO:tensorflow:loss = 0.63659954, step = 1
# INFO:tensorflow:global_step/sec: 6.20326
# INFO:tensorflow:loss = 0.58674264, step = 101 (16.123 sec)
# INFO:tensorflow:global_step/sec: 6.60254
# INFO:tensorflow:loss = 0.51379985, step = 201 (15.146 sec)
# INFO:tensorflow:global_step/sec: 6.6666
# INFO:tensorflow:loss = 0.69095397, step = 301 (15.000 sec)
# INFO:tensorflow:Saving checkpoints for 377 into ./trained_rnn/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:14:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-377
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:14:06
# INFO:tensorflow:Saving dict for global step 377: global_step = 377, loss = 0.53655005, mean_squared_error = 0.5271812
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 377: ./trained_rnn/sines/model.ckpt-377
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-377
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn/sines/export/exporter/temp-b'1575728046'/saved_model.pb
# INFO:tensorflow:global_step/sec: 4.9838
# INFO:tensorflow:loss = 0.57510346, step = 401 (20.068 sec)
# INFO:tensorflow:global_step/sec: 6.65642
# INFO:tensorflow:loss = 0.5881666, step = 501 (15.023 sec)
# INFO:tensorflow:global_step/sec: 6.57557
# INFO:tensorflow:loss = 0.5608354, step = 601 (15.204 sec)
# INFO:tensorflow:global_step/sec: 6.61794
# INFO:tensorflow:loss = 0.5722286, step = 701 (15.111 sec)
# INFO:tensorflow:Saving checkpoints for 741 into ./trained_rnn/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:15:02Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-741
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:15:06
# INFO:tensorflow:Saving dict for global step 741: global_step = 741, loss = 0.5262551, mean_squared_error = 0.5186477
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 741: ./trained_rnn/sines/model.ckpt-741
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-741
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn/sines/export/exporter/temp-b'1575728106'/saved_model.pb
# INFO:tensorflow:global_step/sec: 5.02669
# INFO:tensorflow:loss = 0.5151378, step = 801 (19.897 sec)
# INFO:tensorflow:global_step/sec: 6.46942
# INFO:tensorflow:loss = 0.49427834, step = 901 (15.454 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_rnn/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:15:47Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:15:51
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.5292787, mean_squared_error = 0.5222413
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_rnn/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn/sines/export/exporter/temp-b'1575728151'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.54976016.

# %%
BUCKET = 'qwiklabs-gcp-ml-49b827b781ab'
model="rnn2"
learning_rate=0.01
train_batch_size=100
DATADIR="./data/sines"
OUTDIR="./trained_{}/sines".format(model)
train_data_path="gs://{}/sines/train*.csv".format(BUCKET)
eval_data_path="gs://{}/sines/valid*.csv".format(BUCKET)
eval_delay_secs=10
min_eval_frequency=60

hparams={"train_data_path":train_data_path, "eval_data_path":eval_data_path,
        "train_batch_size":train_batch_size,
        "learning_rate":learning_rate,
        "train_steps":1000,
        "sequence_length":50,
        "output_dir":OUTDIR,
        "model":model,
        "job-dir":OUTDIR,
        "eval_delay_secs":eval_delay_secs,
        "min_eval_frequency":min_eval_frequency
        }

init(hparams)
train_and_evaluate(OUTDIR, hparams)
# Out:
# INFO:tensorflow:Using the Keras model provided.
# INFO:tensorflow:Using config: {'_train_distribute': None, '_global_id_in_cluster': 0, '_protocol': None, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_session_creation_timeout_secs': 7200, '_device_fn': None, '_save_checkpoints_steps': None, '_task_id': 0, '_eval_distribute': None, '_evaluation_master': '', '_master': '', '_num_ps_replicas': 0, '_is_chief': True, '_task_type': 'worker', '_experimental_max_worker_delay_secs': None, '_save_checkpoints_secs': 60, '_service': None, '_model_dir': './trained_rnn2/sines', '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_experimental_distribute': None, '_log_step_count_steps': 100, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f96564007b8>, '_num_worker_replicas': 1}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps None or save_checkpoints_secs 60.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Warm-starting with WarmStartSettings: WarmStartSettings(ckpt_to_initialize_from='./trained_rnn2/sines/keras/keras_model.ckpt', vars_to_warm_start='.*', var_name_to_vocab_info={}, var_name_to_prev_var_name={})
# INFO:tensorflow:Warm-starting from: ./trained_rnn2/sines/keras/keras_model.ckpt
# INFO:tensorflow:Warm-starting variables only in TRAINABLE_VARIABLES.
# INFO:tensorflow:Warm-started 10 variables.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:loss = 0.56839055, step = 1
# INFO:tensorflow:global_step/sec: 2.93441
# INFO:tensorflow:loss = 0.46416906, step = 101 (34.081 sec)
# INFO:tensorflow:Saving checkpoints for 171 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:16:59Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-171
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:17:03
# INFO:tensorflow:Saving dict for global step 171: global_step = 171, loss = 0.52628225, mean_squared_error = 0.52227587
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 171: ./trained_rnn2/sines/model.ckpt-171
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-171
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575728223'/saved_model.pb
# INFO:tensorflow:global_step/sec: 2.65792
# INFO:tensorflow:loss = 0.6233026, step = 201 (37.623 sec)
# INFO:tensorflow:global_step/sec: 3.17354
# INFO:tensorflow:loss = 0.6226701, step = 301 (31.514 sec)
# INFO:tensorflow:Saving checkpoints for 343 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:17:59Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-343
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:18:04
# INFO:tensorflow:Saving dict for global step 343: global_step = 343, loss = 0.5350078, mean_squared_error = 0.52687204
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 343: ./trained_rnn2/sines/model.ckpt-343
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-343
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575728284'/saved_model.pb
# INFO:tensorflow:global_step/sec: 2.66842
# INFO:tensorflow:loss = 0.55496126, step = 401 (37.472 sec)
# INFO:tensorflow:global_step/sec: 3.13355
# INFO:tensorflow:loss = 0.5460324, step = 501 (31.913 sec)
# INFO:tensorflow:Saving checkpoints for 514 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:18:59Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-514
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:19:04
# INFO:tensorflow:Saving dict for global step 514: global_step = 514, loss = 0.5267694, mean_squared_error = 0.5180328
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 514: ./trained_rnn2/sines/model.ckpt-514
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-514
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575728344'/saved_model.pb
# INFO:tensorflow:global_step/sec: 2.61983
# INFO:tensorflow:loss = 0.5677295, step = 601 (38.172 sec)
# INFO:tensorflow:Saving checkpoints for 683 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:20:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-683
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:20:04
# INFO:tensorflow:Saving dict for global step 683: global_step = 683, loss = 0.5342127, mean_squared_error = 0.5238895
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 683: ./trained_rnn2/sines/model.ckpt-683
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-683
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575728404'/saved_model.pb
# INFO:tensorflow:global_step/sec: 2.64789
# INFO:tensorflow:loss = 0.54410386, step = 701 (37.765 sec)
# INFO:tensorflow:global_step/sec: 3.1075
# INFO:tensorflow:loss = 0.5795029, step = 801 (32.183 sec)
# INFO:tensorflow:Saving checkpoints for 851 into ./trained_rnn2/sines/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:21:00Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-851
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:21:05
# INFO:tensorflow:Saving dict for global step 851: global_step = 851, loss = 0.53178054, mean_squared_error = 0.52011794
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 851: ./trained_rnn2/sines/model.ckpt-851
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-851
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575728465'/saved_model.pb
# INFO:tensorflow:global_step/sec: 2.58392
# INFO:tensorflow:loss = 0.53421885, step = 901 (38.698 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into ./trained_rnn2/sines/model.ckpt.
# INFO:tensorflow:Skip the current checkpoint eval due to throttle secs (60 secs).
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-07T14:21:54Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-07-14:21:59
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.53625417, mean_squared_error = 0.52817005
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: ./trained_rnn2/sines/model.ckpt-1000
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Restoring parameters from ./trained_rnn2/sines/model.ckpt-1000
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: ./trained_rnn2/sines/export/exporter/temp-b'1575728519'/saved_model.pb
# INFO:tensorflow:Loss for final step: 0.6051988.
