# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import sklearn
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
print(tf.__version__)
# Out:
# 1.15.0

# %%
tf.enable_eager_execution()

# %%
df = pd.read_csv('./input/train.csv')
df = df.drop('Time', axis=1)
df = df.drop('Amount', axis=1)

print(df.Class.value_counts())
# Out:
# 0    181971
# 1       305
# Name: Class, dtype: int64

# %%
df
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 0      -2.388049 -2.490423  1.888346 -1.313157  0.335402 -0.743883  0.576642
# 1       1.225984  0.212700 -0.157300  1.082289  0.840563  1.184308 -0.127604
# 2      -2.188785 -0.958016  0.769310 -3.102286 -0.242737  0.071822 -0.486386
# 3       2.105378  0.095780 -2.263791  0.091285  0.882610 -0.338245  0.099070
# 4      -0.328728 -0.476626  1.429567 -0.900624  0.067534  2.167218 -0.040161
# ...          ...       ...       ...       ...       ...       ...       ...
# 182271  1.211793 -0.467790 -0.364887 -0.304115  1.422890  3.960385 -1.188066
# 182272 -3.335133 -3.036955  2.031891  3.187473  4.657122 -1.951119 -1.704563
# 182273  1.983675 -0.563139 -0.556800  0.070248 -0.240229  0.532842 -0.824306
# 182274 -0.713810  1.157668  0.776284  0.800797 -0.721380  0.354157  1.796804
# 182275  2.054383 -0.060038 -1.066449  0.408927 -0.115120 -1.130123  0.167008
#
# ...

# %%
df.to_csv('/home/jupyter/google-asl-study/final_mini_project/youn/input/train_time_amount_minus.csv',index=False)

# %%
df = pd.read_csv('./input/train_smote.csv')
df = df.drop('Time', axis=1)
df = df.drop('Amount', axis=1)

df.to_csv('/home/jupyter/google-asl-study/final_mini_project/youn/input/train_smote_time_amount_minus.csv',index=False)

# %%
df = pd.read_csv('./input/valid.csv')
df = df.drop('Time', axis=1)
df = df.drop('Amount', axis=1)

df.to_csv('/home/jupyter/google-asl-study/final_mini_project/youn/input/valid_time_amount_minus.csv',index=False)

# %%
df = pd.read_csv('./input/test.csv')
df = df.drop('Time', axis=1)
df = df.drop('Amount', axis=1)

df.to_csv('/home/jupyter/google-asl-study/final_mini_project/youn/input/test_time_amount_minus.csv',index=False)
