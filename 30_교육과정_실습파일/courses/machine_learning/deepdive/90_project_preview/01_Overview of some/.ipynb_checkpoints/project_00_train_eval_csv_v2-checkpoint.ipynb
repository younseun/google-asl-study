# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('./input/creditcard.csv')
df_train, df_test = train_test_split(df, test_size=0.25, random_state=27)
print(df_train.Class.value_counts())
print(df_test.Class.value_counts())
# Out:
# 0    213245
# 1       360
# Name: Class, dtype: int64
# 0    71070
# 1      132
# Name: Class, dtype: int64

# %%
# !head ./input/creditcard.csv > ./input/creditcard_small.csv
# !head -5 ./input/creditcard_small.csv
# Out:
# "Time","V1","V2","V3","V4","V5","V6","V7","V8","V9","V10","V11","V12","V13","V14","V15","V16","V17","V18","V19","V20","V21","V22","V23","V24","V25","V26","V27","V28","Amount","Class"
# 0,-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62,"0"
# ...

# %%
df_train.to_csv('./input/creditcard_train.csv',index=False)

# %%
df_test.to_csv('./input/creditcard_eval.csv',index=False)

# %%
# !head -5 ./input/creditcard_train.csv
# Out:
# Time,V1,V2,V3,V4,V5,V6,V7,V8,V9,V10,V11,V12,V13,V14,V15,V16,V17,V18,V19,V20,V21,V22,V23,V24,V25,V26,V27,V28,Amount,Class
# 161634.0,-0.39557843555936606,1.48912894043995,-0.833442487716007,-0.22427074174567896,0.36944449839348703,-1.45388589236618,0.7965926979418241,-0.0604030266086433,0.338270045556283,-0.34388490666936405,-0.647990228283319,-0.509490279392573,-0.6337292440504089,-0.71215562468389,0.7657014179574471,0.0538297001193089,0.5262105665430471,0.7505048298181299,-0.225920799155453,0.0541324279611375,0.231623978630871,0.95519446225634,-0.172091617167348,-0.0410499244329146,-0.3134438234105639,-0.174301459085054,0.0646573403859003,-0.0369595506770341,2.74,0
# ...

# %%
# !head -5 ./input/creditcard_eval.csv
# Out:
# Time,V1,V2,V3,V4,V5,V6,V7,V8,V9,V10,V11,V12,V13,V14,V15,V16,V17,V18,V19,V20,V21,V22,V23,V24,V25,V26,V27,V28,Amount,Class
# 43343.0,1.2099708365763002,-0.15808084728396,0.685983619669667,-0.0196814166592577,-0.8740748548289909,-0.7756615773443849,-0.35277101465025795,0.0158347067575591,0.5455786917746129,-0.224425839670672,0.0888004006295991,-0.203061407194497,-1.1134649467454398,0.4108332459618089,1.60733879509397,0.0729045354846847,0.10053874637016699,-0.8314412498558341,-0.44651036141510503,-0.176492249707781,-0.0962617392836623,-0.294659250259797,0.17772823788996397,0.418380937326001,-0.0398140911564451,0.918009765727841,-0.0619614983178352,0.00727595977713399,5.37,0
# ...
